# %%
import Pkg
Pkg.add("Revisit")
# Out:
# The following package names could not be resolved:
#  * Revisit (not found in project, manifest or registry)
#
#
# Stacktrace:
#  [1] pkgerror(::String) at /home/kun/julia-1.4.1/share/julia/stdlib/v1.4/Pkg/src/Types.jl:53
#  [2] ensure_resolved(::Pkg.Types.Context, ::Array{Pkg.Types.PackageSpec,1}; registry::Bool) at /home/kun/julia-1.4.1/share/julia/stdlib/v1.4/Pkg/src/Types.jl:794
#  [3] add(::Pkg.Types.Context, ::Array{Pkg.Types.PackageSpec,1}; preserve::Pkg.Types.PreserveLevel, platform::Pkg.BinaryPlatforms.Linux, kwargs::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at /home/kun/julia-1.4.1/share/julia/stdlib/v1.4/Pkg/src/API.jl:148
#  [4] add(::Pkg.Types.Context, ::Array{Pkg.Types.PackageSpec,1}) at /home/kun/julia-1.4.1/share/julia/stdlib/v1.4/Pkg/src/API.jl:112
#  [5] #add#27 at /home/kun/julia-1.4.1/share/julia/stdlib/v1.4/Pkg/src/API.jl:109 [inlined]
#  [6] add at /home/kun/julia-1.4.1/share/julia/stdlib/v1.4/Pkg/src/API.jl:109 [inlined]
# ...

# %%
using Revise
# Out:
# ┌ Info: Precompiling Revise [295af30f-e4ad-537b-8983-00126c2a3abe]
# └ @ Base loading.jl:1260

# %%
include("polar.jl")
# Out:
# Loading polar_pid0.jld2
# Loading polar_pid1.jld2
# Loading polar_pid10.jld2
# Loading polar_pid11.jld2
# Loading polar_pid12.jld2
# Loading polar_pid13.jld2
# Loading polar_pid14.jld2
# Loading polar_pid15.jld2
# Loading polar_pid16.jld2
# Loading polar_pid17.jld2
# Loading polar_pid18.jld2
# Loading polar_pid19.jld2
# Loading polar_pid2.jld2
# Loading polar_pid20.jld2
# Loading polar_pid21.jld2
# Loading polar_pid22.jld2
# Loading polar_pid23.jld2
# Loading polar_pid24.jld2
# Loading polar_pid25.jld2
# Loading polar_pid26.jld2
# Loading polar_pid27.jld2
# Loading polar_pid28.jld2
# Loading polar_pid29.jld2
# Loading polar_pid3.jld2
# Loading polar_pid30.jld2
# Loading polar_pid4.jld2
# Loading polar_pid5.jld2
# Loading polar_pid6.jld2
# Loading polar_pid7.jld2
# Loading polar_pid8.jld2
# Loading polar_pid9.jld2
# ...

# %%
using Plots

# %%
include("polar.jl")
# Out:
# Loading polar_pid0.jld2
# Loading polar_pid1.jld2
# Loading polar_pid10.jld2
# Loading polar_pid11.jld2
# Loading polar_pid12.jld2
# Loading polar_pid13.jld2
# Loading polar_pid14.jld2
# Loading polar_pid15.jld2
# Loading polar_pid16.jld2
# Loading polar_pid17.jld2
# Loading polar_pid18.jld2
# Loading polar_pid19.jld2
# Loading polar_pid2.jld2
# Loading polar_pid20.jld2
# Loading polar_pid21.jld2
# Loading polar_pid22.jld2
# Loading polar_pid23.jld2
# Loading polar_pid24.jld2
# Loading polar_pid25.jld2
# Loading polar_pid26.jld2
# Loading polar_pid27.jld2
# Loading polar_pid28.jld2
# Loading polar_pid29.jld2
# Loading polar_pid3.jld2
# Loading polar_pid30.jld2
# Loading
# WARNING: redefining constant ReWeight
# WARNING: replacing module Grid.
# polar_pid4.jld2
# Loading polar_pid5.jld2
# Loading polar_pid6.jld2
# Loading polar_pid7.jld2
# Loading polar_pid8.jld2
# Loading polar_pid9.jld2
# ...

# %%
polar
# Out:
# 64-element Array{Any,1}:
#  1.600287875584743e-5
#  1.5438727251315213e-5
#  1.4567353698706296e-5
#  1.5321742306577982e-5
#  1.5579765052142773e-5
#  1.5603817995045386e-5
#  1.5861840755441124e-5
#  1.5903386756107653e-5
#  1.5471526593648486e-5
#  1.5895733499010854e-5
#  1.5713149540768826e-5
#  1.56344307319274e-5
#  1.547371313862518e-5
#  ⋮
#  2.2675389503901755e-6
#  2.2423926660863717e-6
#  2.0445023245723686e-6
#  1.9187708901401753e-6
#  2.009516176314145e-6
#  1.8553585103421567e-6
#  1.9646901952976704e-6
#  1.877224844725055e-6
#  1.79194613757606e-6
#  1.814905787278112e-6
#  1.6268553044765483e-6
#  1.621388718163945e-6

# %%
plot(MomGrid/Kf, polar)
